# %% [markdown]
# # <span style="color:red">Calories Burnt Prediction</span>

# %% [markdown]
# # <span style="background-color: #FFE4B5; padding: 10px"><strong>**IMPORTING LIBRARIES:**</strong></span>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # <span style="background-color: #FFE4B5; padding: 10px"><strong>**LOADING DATASET:**</strong></span>

# %%
# loading the data from csv file to a Pandas DataFrame
calories = pd.read_csv('calories.csv')

# %%
# print the first 5 rows of the dataframe
calories.head()
# Out:
#     User_ID  Calories
# 0  14733363     231.0
# 1  14861698      66.0
# 2  11179863      26.0
# 3  16180408      71.0
# 4  17771927      35.0

# %%
exercise_data = pd.read_csv('exercise.csv')

# %%
exercise_data.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8

# %%
# Combining the two Dataframes
df = pd.concat([exercise_data, calories['Calories']], axis=1)

# %%
df.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8
#
#    Calories
# 0     231.0
# 1      66.0
# 2      26.0
# 3      71.0
# 4      35.0

# %% [markdown]
# # <span style="background-color: #FFE4B5; padding: 10px"><strong>**BACIS UNDERSTATNDING OF DATASET:**</strong></span>

# %% [markdown]
# ### 1. Checking the Dimensions of Dataset.

# %%
print("Total Number of records/ rows present in the dataset is: ", df.shape[0])
print("Total Number of columns present in the dataset is: ", df.shape[1])
# Out:
# Total Number of records/ rows present in the dataset is:  15000
# Total Number of columns present in the dataset is:  9

# %% [markdown]
# ### 2. Fetching the attributes Name

# %%
df.columns
# Out:
# Index(['User_ID', 'Gender', 'Age', 'Height', 'Weight', 'Duration',
#        'Heart_Rate', 'Body_Temp', 'Calories'],
#       dtype='object')

# %% [markdown]
# ### 3. Generating Basic Information of the data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     15000 non-null  int64
#  1   Gender      15000 non-null  object
#  2   Age         15000 non-null  int64
#  3   Height      15000 non-null  float64
#  4   Weight      15000 non-null  float64
#  5   Duration    15000 non-null  float64
#  6   Heart_Rate  15000 non-null  float64
#  7   Body_Temp   15000 non-null  float64
#  8   Calories    15000 non-null  float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 1.0+ MB

# %% [markdown]
# ### **Observations**:
# Dataset contains 15000 rows and 9 columns.
#
# Out of 15 , 6 columns are of float datatype, 2 are of int, 1 are of object datatype.

# %% [markdown]
# ### 4. Checking for null values

# %%
df.isnull().sum()
# Out:
# User_ID       0
# Gender        0
# Age           0
# Height        0
# Weight        0
# Duration      0
# Heart_Rate    0
# Body_Temp     0
# Calories      0
# dtype: int64

# %% [markdown]
# ### **Observations:**
#     There are not null values present in our dataset.

# %% [markdown]
# ### 5. Checking for Duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### **Observation:**
# There is no duplicate records present in our dataset

# %% [markdown]
# ### 7. Basic statistical information about dataset

# %%
df.describe()
# Out:
#             User_ID           Age        Height        Weight      Duration  \
# count  1.500000e+04  15000.000000  15000.000000  15000.000000  15000.000000
# mean   1.497736e+07     42.789800    174.465133     74.966867     15.530600
# std    2.872851e+06     16.980264     14.258114     15.035657      8.319203
# min    1.000116e+07     20.000000    123.000000     36.000000      1.000000
# 25%    1.247419e+07     28.000000    164.000000     63.000000      8.000000
# 50%    1.499728e+07     39.000000    175.000000     74.000000     16.000000
# 75%    1.744928e+07     56.000000    185.000000     87.000000     23.000000
# max    1.999965e+07     79.000000    222.000000    132.000000     30.000000
#
#          Heart_Rate     Body_Temp      Calories
# count  15000.000000  15000.000000  15000.000000
# mean      95.518533     40.025453     89.539533
# std        9.583328      0.779230     62.456978
# min       67.000000     37.100000      1.000000
# 25%       88.000000     39.600000     35.000000
# 50%       96.000000     40.200000     79.000000
# 75%      103.000000     40.600000    138.000000
# max      128.000000     41.500000    314.000000

# %%
df['BMI'] = round(df['Weight'] / ((df['Height'] / 100) ** 2), 1)

# %%
df.head()
# Out:
#     User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0  14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1  14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2  11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3  16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4  17771927  female   27   154.0    58.0      10.0        81.0       39.8
#
#    Calories   BMI
# 0     231.0  26.0
# 1      66.0  21.8
# 2      26.0  24.7
# 3      71.0  22.2
# 4      35.0  24.5

# %% [markdown]
# # <span style="background-color: #FFE4B5; padding: 10px"><strong>**EXPLORATORY DATA ANALYSIS:**</strong></span>

# %% [markdown]
# # 1. What is the distribution of the target variable 'Calories'? Is it skewed?

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df['Calories'], bins=30, kde=True, color='blue')
plt.title('Distribution of Calories')
plt.xlabel('Calories')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### **Observation**
# By observing the above plot, we can conclude that the 'Calories' column is right-skewed as it contains some outliers. However, we have decided not to remove them because there is a possibility that people who exercise more burn a higher number of calories. Therefore, we are retaining the outliers as they may provide valuable information about higher calorie expenditure during intense exercise sessions.

# %% [markdown]
# # 2. How does the distribution of calories burned vary between different genders?

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(data=df, x='Calories', hue='Gender', fill=True, common_norm=False, palette='Set2')
plt.title('Calories Burned by Gender')
plt.xlabel('Calories Burned')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# ### **Observation**
# By observing the above KDE chart, we can say that calories burned among males and females are almost the same, but both are slightly right-skewed.

# %% [markdown]
# # 3. How does the distribution change across different age?

# %%
sns.jointplot(data=df, x='Age', y='Calories', kind='reg', color='purple')
plt.suptitle('Relationship Between Age and Calories Burned', y=1.02)
plt.show()

# %% [markdown]
# # 4.  Is there a clear relationship between the duration of the activity and the calories burned?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.regplot(data=df, x='Duration', y='Calories', scatter_kws={'alpha': 0.3, 'color': 'orange'}, line_kws={'color': 'purple'})
plt.title('Regression Plot of Calories Burned vs. Duration')
plt.xlabel('Duration (minutes)')
plt.ylabel('Calories Burned')
plt.show()

# %% [markdown]
# ### **Observation::**
#         From the above regression plot, it is clear that the duration of the activity and the calories burned are positively correlated. As the duration of the activity increases, the number of calories burned also increases.

# %% [markdown]
# # 5. How does heart rate correlate with the number of calories burned during physical activities?

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Heart_Rate', y='Calories', alpha=0.7, color='green')
plt.title('Scatter Plot of Heart Rate vs. Calories Burned')
plt.xlabel('Heart Rate')
plt.ylabel('Calories Burned')
plt.show()

# %% [markdown]
# # **Observation:**
#     By observing the above chart, it is evident that as heart rate increases, the rate of calories burned also increases.
#     This could be attributed to the possibility that, during more intensive exercises, such as running, the heart rate is higher, resulting in a greater calorie expenditure. Conversely, when engaging in low-intensity activities like walking, the heart rate is lower, and calories burned are also lower.

# %% [markdown]
# # 6. How does BMI correlate with calories expended?

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='BMI', y='Calories', alpha=0.7, color='purple')
plt.title('Scatter Plot of BMI vs. Calories Burned')
plt.xlabel('BMI')
plt.ylabel('Calories Burned')
plt.show()

# %% [markdown]
# # 7. Is there any noticeable relationship between body temperature and calories burned?

# %%
plt.figure(figsize=(10, 6))
sns.regplot(data=df, x='Body_Temp', y='Calories', scatter_kws={'alpha': 0.3, 'color': 'orange'}, line_kws={'color': 'purple'})
plt.title('Regression Plot of Body Temperature vs. Calories Burned')
plt.xlabel('Body Temperature')
plt.ylabel('Calories Burned')
plt.show()

# %% [markdown]
# ### **Observation:**
#     As body temperature increases, there is a corresponding rise in calories burned, potentially indicating a connection to the intensity of exercise.

# %% [markdown]
# # <span style="background-color: #FFE4B5; padding: 10px"><strong>**Converting Catergories to Numbers:**</strong></span>

# %%
df["Gender"].value_counts()
# Out:
# female    7553
# male      7447
# Name: Gender, dtype: int64

# %%
df["Gender"]= df["Gender"].map({"female": 0, "male": 1})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     15000 non-null  int64
#  1   Gender      15000 non-null  int64
#  2   Age         15000 non-null  int64
#  3   Height      15000 non-null  float64
#  4   Weight      15000 non-null  float64
#  5   Duration    15000 non-null  float64
#  6   Heart_Rate  15000 non-null  float64
#  7   Body_Temp   15000 non-null  float64
#  8   Calories    15000 non-null  float64
#  9   BMI         15000 non-null  float64
# dtypes: float64(7), int64(3)
# memory usage: 1.1 MB

# %% [markdown]
# # <span style="background-color: #FFE4B5; padding: 10px"><strong>**Corelation metrics:**</strong></span>

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot= True)
plt.show()

# %%
df.columns
# Out:
# Index(['User_ID', 'Gender', 'Age', 'Height', 'Weight', 'Duration',
#        'Heart_Rate', 'Body_Temp', 'Calories', 'BMI'],
#       dtype='object')

# %% [markdown]
# # <span style="background-color: #FFE4B5; padding: 10px"><strong>**splitting the data into X and y:**</strong></span>

# %%
x= df.drop(["User_ID", "Height", "Weight"], axis= 1)

# %%
x.head()
# Out:
#    Gender  Age  Duration  Heart_Rate  Body_Temp  Calories   BMI
# 0       1   68      29.0       105.0       40.8     231.0  26.0
# 1       0   20      14.0        94.0       40.3      66.0  21.8
# 2       1   69       5.0        88.0       38.7      26.0  24.7
# 3       0   34      13.0       100.0       40.5      71.0  22.2
# 4       0   27      10.0        81.0       39.8      35.0  24.5

# %%
y = df["Calories"]

# %%
y.head()
# Out:
# 0    231.0
# 1     66.0
# 2     26.0
# 3     71.0
# 4     35.0
# Name: Calories, dtype: float64

# %% [markdown]
# #  <span style="background-color: #FFE4B5; padding: 10px"><strong>**Scaling:**</strong></span>

# %%
# applying 'for loop' to bring all the variables in rabge 0 to 1
for i in x.columns[:]:
    x[i]  = (x[i] - x[i].min()) / (x[i].max() - x[i].min())

# %%
x.head()
# Out:
#    Gender       Age  Duration  Heart_Rate  Body_Temp  Calories       BMI
# 0     1.0  0.813559  0.965517    0.622951   0.840909  0.734824  0.686869
# 1     0.0  0.000000  0.448276    0.442623   0.727273  0.207668  0.262626
# 2     1.0  0.830508  0.137931    0.344262   0.363636  0.079872  0.555556
# 3     0.0  0.237288  0.413793    0.540984   0.772727  0.223642  0.303030
# 4     0.0  0.118644  0.310345    0.229508   0.613636  0.108626  0.535354

# %% [markdown]
# #  <span style="background-color: #FFE4B5; padding: 10px"><strong>**Split Training and Testing data:**</strong></span>

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.30, random_state=123)

# %% [markdown]
# # <span style="background-color: #FFE4B5; padding: 10px"><strong>**Defining Architecture of the Neural Network:**</strong></span>

# %%
# important libraries
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import InputLayer, Dense
from sklearn.metrics import mean_absolute_error, r2_score

# %% [markdown]
# # <span style="background-color: #FFE4B5; padding: 10px"><strong>**Defining different layers in out model:**</strong></span>

# %%
# defining input neurons
input_neurons = xtrain.shape[1]
print(f'Number of input Neurons : {input_neurons}')
# Out:
# Number of input Neurons : 7

# %% [markdown]
# # <span style="background-color: #FFE4B5; padding: 10px"><strong>**Model Architecture:**</strong></span>

# %%
# Model 1
model1 = Sequential()
model1.add(InputLayer(input_shape= (input_neurons,))) #adding Layers
model1.add(Dense(8 ,activation='relu')) # set number of neurons using units
model1.add(Dense(1 ,activation='linear'))

# %%
# model 2
model2 = Sequential()
model2.add(InputLayer(input_shape= (input_neurons,)))
model2.add(Dense(8 ,activation='relu'))
model2.add(Dense(16 ,activation='relu'))
model2.add(Dense(1 ,activation='linear'))

# %%
# model 3
model3 = Sequential()
model3.add(InputLayer(input_shape= (input_neurons,)))
model3.add(Dense(20 ,activation='relu'))
model3.add(Dense(10 ,activation='relu'))
model3.add(Dense(1 ,activation='linear'))

# %%
# model 4
model4 = Sequential()
model4.add(InputLayer(input_shape= (input_neurons,)))
model4.add(Dense(20 ,activation='relu'))
model4.add(Dense(1 ,activation='linear'))

# %%
# model 4
model5 = Sequential()
model5.add(InputLayer(input_shape= (input_neurons,)))
model5.add(Dense(10 ,activation='relu'))
model5.add(Dense(20 ,activation='relu'))
model5.add(Dense(1 ,activation='linear'))

# %%
# model 1 summary
model1.summary()

print("#"*100)
print("#"*100)

# model 2 summary
model2.summary()

print("#"*100)
print("#"*100)

# model 3 summary
model3.summary()

print("#"*100)
print("#"*100)

# model 4 summary
model4.summary()
print("#"*100)
print("#"*100)

# model 5 summary
model5.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 64
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 73 (292.00 Byte)
# Trainable params: 73 (292.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# ####################################################################################################
# ####################################################################################################
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 8)                 64
#
#  dense_3 (Dense)             (None, 16)                144
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 225 (900.00 Byte)
# Trainable params: 225 (900.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# ####################################################################################################
# ####################################################################################################
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 20)                160
#
#  dense_6 (Dense)             (None, 10)                210
#
#  dense_7 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 381 (1.49 KB)
# Trainable params: 381 (1.49 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# ####################################################################################################
# ####################################################################################################
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, 20)                160
#
#  dense_17 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 181 (724.00 Byte)
# Trainable params: 181 (724.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# ####################################################################################################
# ####################################################################################################
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_13 (Dense)            (None, 10)                80
#
#  dense_14 (Dense)            (None, 20)                220
#
#  dense_15 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 321 (1.25 KB)
# Trainable params: 321 (1.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # Compiling all Models (defining loss function, optimizer)

# %%
model1.compile(loss='mean_absolute_error',optimizer='Adam')

# %%
model2.compile(loss='mean_absolute_error',optimizer='Adam')

# %%
model3.compile(loss='mean_absolute_error',optimizer='Adam')

# %%
model4.compile(loss='mean_absolute_error',optimizer='Adam')

# %%
model5.compile(loss='mean_absolute_error',optimizer='Adam')

# %% [markdown]
# # Training Models

# %%
model1_history = model1.fit(xtrain, ytrain, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 263/263 [==============================] - 3s 5ms/step - loss: 87.2822 - val_loss: 87.0966
# Epoch 2/50
# 263/263 [==============================] - 1s 3ms/step - loss: 81.3403 - val_loss: 79.5115
# Epoch 3/50
# 263/263 [==============================] - 1s 4ms/step - loss: 72.5800 - val_loss: 69.7981
# Epoch 4/50
# 263/263 [==============================] - 1s 3ms/step - loss: 62.7597 - val_loss: 60.0233
# Epoch 5/50
# 263/263 [==============================] - 1s 3ms/step - loss: 53.7387 - val_loss: 51.4958
# Epoch 6/50
# 263/263 [==============================] - 1s 4ms/step - loss: 46.4920 - val_loss: 44.9373
# Epoch 7/50
# 263/263 [==============================] - 1s 3ms/step - loss: 41.1999 - val_loss: 40.1544
# Epoch 8/50
# 263/263 [==============================] - 1s 3ms/step - loss: 37.3939 - val_loss: 36.6736
# Epoch 9/50
# 263/263 [==============================] - 1s 3ms/step - loss: 34.3578 - val_loss: 33.7510
# Epoch 10/50
# 263/263 [==============================] - 1s 3ms/step - loss: 31.6018 - val_loss: 30.9640
# Epoch 11/50
# 263/263 [==============================] - 1s 4ms/step - loss: 28.8318 - val_loss: 28.1375
# Epoch 12/50
# 263/263 [==============================] - 1s 4ms/step - loss: 25.9790 - val_loss: 25.2071
# Epoch 13/50
# 263/263 [==============================] - 1s 3ms/step - loss: 23.0106 - val_loss: 22.1573
# Epoch 14/50
# 263/263 [==============================] - 1s 3ms/step - loss: 19.9700 - val_loss: 19.0715
# Epoch 15/50
# 263/263 [==============================] - 1s 4ms/step - loss: 16.9266 - val_loss: 16.0926
# Epoch 16/50
# 263/263 [==============================] - 1s 3ms/step - loss: 14.2235 - val_loss: 13.6675
# Epoch 17/50
# 263/263 [==============================] - 1s 3ms/step - loss: 12.1476 - val_loss: 11.7990
# Epoch 18/50
# 263/263 [==============================] - 1s 3ms/step - loss: 10.5967 - val_loss: 10.3768
# Epoch 19/50
# 263/263 [==============================] - 1s 3ms/step - loss: 9.4319 - val_loss: 9.2879
# Epoch 20/50
# 263/263 [==============================] - 1s 4ms/step - loss: 8.4952 - val_loss: 8.3799
# Epoch 21/50
# 263/263 [==============================] - 1s 4ms/step - loss: 7.7984 - val_loss: 7.7506
# Epoch 22/50
# 263/263 [==============================] - 1s 4ms/step - loss: 7.3193 - val_loss: 7.2936
# Epoch 23/50
# 263/263 [==============================] - 1s 4ms/step - loss: 6.9712 - val_loss: 6.9575
# Epoch 24/50
# 263/263 [==============================] - 1s 3ms/step - loss: 6.7078 - val_loss: 6.7255
# Epoch 25/50
# 263/263 [==============================] - 1s 4ms/step - loss: 6.4874 - val_loss: 6.4826
# Epoch 26/50
# 263/263 [==============================] - 1s 4ms/step - loss: 6.2942 - val_loss: 6.2800
# Epoch 27/50
# 263/263 [==============================] - 1s 3ms/step - loss: 6.1100 - val_loss: 6.0948
# Epoch 28/50
# 263/263 [==============================] - 1s 3ms/step - loss: 5.9330 - val_loss: 5.9177
# Epoch 29/50
# 263/263 [==============================] - 1s 4ms/step - loss: 5.7711 - val_loss: 5.7603
# Epoch 30/50
# 263/263 [==============================] - 1s 4ms/step - loss: 5.6056 - val_loss: 5.5981
# Epoch 31/50
# 263/263 [==============================] - 1s 4ms/step - loss: 5.4544 - val_loss: 5.4403
# Epoch 32/50
# 263/263 [==============================] - 1s 3ms/step - loss: 5.3064 - val_loss: 5.2953
# Epoch 33/50
# 263/263 [==============================] - 1s 3ms/step - loss: 5.1694 - val_loss: 5.2126
# Epoch 34/50
# 263/263 [==============================] - 1s 3ms/step - loss: 5.0370 - val_loss: 5.0165
# Epoch 35/50
# 263/263 [==============================] - 1s 3ms/step - loss: 4.9118 - val_loss: 4.9033
# Epoch 36/50
# 263/263 [==============================] - 1s 3ms/step - loss: 4.7942 - val_loss: 4.7678
# Epoch 37/50
# 263/263 [==============================] - 1s 4ms/step - loss: 4.6733 - val_loss: 4.6393
# Epoch 38/50
# 263/263 [==============================] - 1s 4ms/step - loss: 4.5615 - val_loss: 4.5594
# Epoch 39/50
# 263/263 [==============================] - 1s 3ms/step - loss: 4.4524 - val_loss: 4.4322
# Epoch 40/50
# 263/263 [==============================] - 1s 3ms/step - loss: 4.3452 - val_loss: 4.3085
# Epoch 41/50
# 263/263 [==============================] - 1s 3ms/step - loss: 4.2445 - val_loss: 4.2124
# Epoch 42/50
# 263/263 [==============================] - 1s 3ms/step - loss: 4.1493 - val_loss: 4.1185
# Epoch 43/50
# 263/263 [==============================] - 1s 3ms/step - loss: 4.0622 - val_loss: 4.0263
# Epoch 44/50
# 263/263 [==============================] - 1s 4ms/step - loss: 3.9731 - val_loss: 3.9694
# Epoch 45/50
# 263/263 [==============================] - 1s 3ms/step - loss: 3.8915 - val_loss: 3.8628
# Epoch 46/50
# 263/263 [==============================] - 1s 3ms/step - loss: 3.8155 - val_loss: 3.7849
# Epoch 47/50
# 263/263 [==============================] - 1s 3ms/step - loss: 3.7429 - val_loss: 3.7150
# Epoch 48/50
# 263/263 [==============================] - 1s 3ms/step - loss: 3.6675 - val_loss: 3.6375
# Epoch 49/50
# 263/263 [==============================] - 1s 3ms/step - loss: 3.5954 - val_loss: 3.5720
# Epoch 50/50
# 263/263 [==============================] - 1s 3ms/step - loss: 3.5254 - val_loss: 3.5204

# %%
ypred1 = model1.predict(xtest)
# Out:
# 141/141 [==============================] - 1s 2ms/step

# %%
ypred1_train= model1.predict(xtrain)
# Out:
# 329/329 [==============================] - 1s 2ms/step

# %%
pred1= r2_score(ytest,ypred1)
print(pred1)
# Out:
# 0.9935545915664944

# %%
pred1= r2_score(ytrain,ypred1_train)
print(pred1)
# Out:
# 0.9935845709108806

# %%
plt.figure(figsize=(10,4))
plt.plot(model1_history.history['loss'])
plt.plot(model1_history.history['val_loss'])   # validation loss values

plt.title('Model 1 Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','validation'], loc='upper right')

plt.show()

# %%
model2_history = model2.fit(xtrain, ytrain, epochs=75, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/75
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0691 - val_loss: 0.0607
# Epoch 2/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0801 - val_loss: 0.1561
# Epoch 3/75
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0744 - val_loss: 0.0219
# Epoch 4/75
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0675 - val_loss: 0.0200
# Epoch 5/75
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0500 - val_loss: 0.0371
# Epoch 6/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0594 - val_loss: 0.0790
# Epoch 7/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0696 - val_loss: 0.0445
# Epoch 8/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0654 - val_loss: 0.0233
# Epoch 9/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0587 - val_loss: 0.0318
# Epoch 10/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0660 - val_loss: 0.2224
# Epoch 11/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0737 - val_loss: 0.0748
# Epoch 12/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0570 - val_loss: 0.0369
# Epoch 13/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0689 - val_loss: 0.0225
# Epoch 14/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0695 - val_loss: 0.0742
# Epoch 15/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0926 - val_loss: 0.0777
# Epoch 16/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0634 - val_loss: 0.0684
# Epoch 17/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0490 - val_loss: 0.0227
# Epoch 18/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0630 - val_loss: 0.0444
# Epoch 19/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0574 - val_loss: 0.0683
# Epoch 20/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0572 - val_loss: 0.0292
# Epoch 21/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0413 - val_loss: 0.0584
# Epoch 22/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0885 - val_loss: 0.0227
# Epoch 23/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0580 - val_loss: 0.0200
# Epoch 24/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0775 - val_loss: 0.1125
# Epoch 25/75
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0968 - val_loss: 0.1065
# Epoch 26/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0773 - val_loss: 0.1050
# Epoch 27/75
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0642 - val_loss: 0.0417
# Epoch 28/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0543 - val_loss: 0.0711
# Epoch 29/75
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0865 - val_loss: 0.1413
# Epoch 30/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.1113 - val_loss: 0.0593
# Epoch 31/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0483 - val_loss: 0.0517
# Epoch 32/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0752 - val_loss: 0.0624
# Epoch 33/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0482 - val_loss: 0.0411
# Epoch 34/75
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0569 - val_loss: 0.0333
# Epoch 35/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0624 - val_loss: 0.1485
# Epoch 36/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0551 - val_loss: 0.0609
# Epoch 37/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0751 - val_loss: 0.0651
# Epoch 38/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0656 - val_loss: 0.0358
# Epoch 39/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0641 - val_loss: 0.0317
# Epoch 40/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0479 - val_loss: 0.0927
# Epoch 41/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0640 - val_loss: 0.0541
# Epoch 42/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0521 - val_loss: 0.0667
# Epoch 43/75
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0770 - val_loss: 0.0487
# Epoch 44/75
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0625 - val_loss: 0.0923
# Epoch 45/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0668 - val_loss: 0.0920
# Epoch 46/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0741 - val_loss: 0.1244
# Epoch 47/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0605 - val_loss: 0.0174
# Epoch 48/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0613 - val_loss: 0.1139
# Epoch 49/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0677 - val_loss: 0.1215
# Epoch 50/75
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0853 - val_loss: 0.1222
# Epoch 51/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0904 - val_loss: 0.0872
# Epoch 52/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0709 - val_loss: 0.0902
# Epoch 53/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0592 - val_loss: 0.0913
# Epoch 54/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0653 - val_loss: 0.1396
# Epoch 55/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0876 - val_loss: 0.0363
# Epoch 56/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0558 - val_loss: 0.0275
# Epoch 57/75
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0648 - val_loss: 0.0188
# Epoch 58/75
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0622 - val_loss: 0.0589
# Epoch 59/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0759 - val_loss: 0.0242
# Epoch 60/75
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0481 - val_loss: 0.1377
# Epoch 61/75
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0877 - val_loss: 0.1219
# Epoch 62/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0947 - val_loss: 0.1829
# Epoch 63/75
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0734 - val_loss: 0.0513
# Epoch 64/75
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0574 - val_loss: 0.1306
# Epoch 65/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0696 - val_loss: 0.0343
# Epoch 66/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0668 - val_loss: 0.0447
# Epoch 67/75
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0681 - val_loss: 0.0303
# Epoch 68/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0758 - val_loss: 0.0235
# Epoch 69/75
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0612 - val_loss: 0.0459
# Epoch 70/75
# 132/132 [==============================] - 1s 4ms/step - loss: 0.0721 - val_loss: 0.0652
# Epoch 71/75
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0590 - val_loss: 0.0376
# Epoch 72/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0508 - val_loss: 0.0325
# Epoch 73/75
# 132/132 [==============================] - 0s 3ms/step - loss: 0.0657 - val_loss: 0.1274
# Epoch 74/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0578 - val_loss: 0.0180
# Epoch 75/75
# 132/132 [==============================] - 0s 4ms/step - loss: 0.0618 - val_loss: 0.0463

# %%
ypred2 = model2.predict(xtest)
# Out:
# 141/141 [==============================] - 0s 2ms/step

# %%
ypred2_train= model2.predict(xtrain)
# Out:
# 329/329 [==============================] - 1s 2ms/step

# %%
pred2= r2_score(ytest,ypred2)
print(pred2)
# Out:
# 0.9999989272423279

# %%
pred2= r2_score(ytrain,ypred2_train)
print(pred1)
# Out:
# 0.9935845709108806

# %%
plt.figure(figsize=(10,4))
plt.plot(model2_history.history['loss'])
plt.plot(model2_history.history['val_loss'])   # validation loss values

plt.title('Model 2 Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','validation'], loc='upper right')

plt.show()
